# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
customers_df_c = pd.read_csv(r"D:\Sasi\GUVI HCL AI-ML\Cart2Insights_Project\data\cleaned_datasets\customers.csv")
orders_df_c = pd.read_csv(r"D:\Sasi\GUVI HCL AI-ML\Cart2Insights_Project\data\cleaned_datasets\orders.csv")
products_df_c = pd.read_csv(r"D:\Sasi\GUVI HCL AI-ML\Cart2Insights_Project\data\cleaned_datasets\products.csv")
sellers_df_c = pd.read_csv(r"D:\Sasi\GUVI HCL AI-ML\Cart2Insights_Project\data\cleaned_datasets\sellers.csv")
order_payments_df_c = pd.read_csv(r"D:\Sasi\GUVI HCL AI-ML\Cart2Insights_Project\data\cleaned_datasets\order_payments.csv")
order_reviews_df_c = pd.read_csv(r"D:\Sasi\GUVI HCL AI-ML\Cart2Insights_Project\data\cleaned_datasets\order_reviews.csv")
order_items_df_c = pd.read_csv(r"D:\Sasi\GUVI HCL AI-ML\Cart2Insights_Project\data\cleaned_datasets\order_items.csv")
product_category_transalation_df_c = pd.read_csv(r"D:\Sasi\GUVI HCL AI-ML\Cart2Insights_Project\data\cleaned_datasets\product_category_translation.csv")
geolocation_df_c = pd.read_csv(r"D:\Sasi\GUVI HCL AI-ML\Cart2Insights_Project\data\cleaned_datasets\geolocation.csv")

# %%
orders_df_c.dtypes
# Out:
# order_id                         str
# customer_id                      str
# order_status                     str
# order_purchase_timestamp         str
# order_approved_at                str
# order_delivered_carrier_date     str
# order_delivered_customer_date    str
# order_estimated_delivery_date    str
# dtype: object

# %% [raw]
# import pandas as pd
# import numpy as np
# import mysql.connector
#
# # 1. Connect and Load Raw Tables into Pandas Dataframes
# conn = mysql.connector.connect(
#     host="localhost",
#     user="root",
#     password="@44872Sasi",
#     database="cart2insights"
# )
#
# print("📥 Loading tables into Pandas dataframes...")
# orders = pd.read_sql("SELECT * FROM orders WHERE order_status = 'delivered'", conn)
# order_items = pd.read_sql("SELECT * FROM order_items", conn)
# products = pd.read_sql("SELECT * FROM products", conn)
# order_payments = pd.read_sql("SELECT * FROM order_payments", conn)
# conn.close()
#
# # 2. Convert Date Columns to Datetime Objects
# print("⏳ Processing datetime features...")
# date_cols = [
#     'order_purchase_timestamp',
#     'order_delivered_carrier_date',
#     'order_delivered_customer_date',
#     'order_estimated_delivery_date'
# ]
# for col in date_cols:
#     orders[col] = pd.to_datetime(orders[col])
#
# # --- FEATURE GROUP 1: LOGISTICS & TIMING (Orders Table) ---
# # Actual delivery time (Purchase to Customer)
# orders['feat_actual_delivery_days'] = (orders['order_delivered_customer_date'] - orders['order_purchase_timestamp']).dt.days
#
# # Delivery discrepancy (Estimated vs Actual) -> Negative means LATE
# orders['feat_days_before_deadline'] = (orders['order_estimated_delivery_date'] - orders['order_delivered_customer_date']).dt.days
#
# # Handling time (Purchase to Carrier)
# orders['feat_seller_handling_days'] = (orders['order_delivered_carrier_date'] - orders['order_purchase_timestamp']).dt.days
#
# # Time-of-day/Seasonality features
# orders['feat_purchase_hour'] = orders['order_purchase_timestamp'].dt.hour
# orders['feat_purchase_day_of_week'] = orders['order_purchase_timestamp'].dt.dayofweek
# orders['feat_purchase_month'] = orders['order_purchase_timestamp'].dt.month
#
#
# # --- FEATURE GROUP 2: PHYSICAL PRODUCT METRICS (Products & Items) ---
# print("📦 Merging and engineering product metrics...")
# # Calculate product dimensions before aggregation
# products['product_volume_cm3'] = products['product_length_cm'] * products['product_height_cm'] * products['product_width_cm']
#
# # Join items with product specs
# items_with_specs = order_items.merge(products, on='product_id', how='left')
#
# # Aggregate data by order_id
# order_items_features = items_with_specs.groupby('order_id').agg(
#     total_items_in_order=('order_item_id', 'count'),
#     total_order_price=('price', 'sum'),
#     total_freight_cost=('freight_value', 'sum'),
#     avg_product_weight_g=('product_weight_g', 'mean'),
#     avg_product_volume_cm3=('product_volume_cm3', 'mean')
# ).reset_index()
#
# # Add a ratio feature
# order_items_features['feat_freight_to_price_ratio'] = (
#     order_items_features['total_freight_cost'] / order_items_features['total_order_price']
# )
#
#
# # --- FEATURE GROUP 3: PAYMENT STRATEGIES (Payments Table) ---
# print("💳 Aggregating payment methods...")
# # Get the maximum installments and dominant payment method per order
# payment_features = order_payments.groupby('order_id').agg(
#     feat_max_payment_installments=('payment_installments', 'max'),
#     primary_payment_type=('payment_type', 'max') # Quick way to pull a payment type string
# ).reset_index()
#
#
# # --- STEP 4: MERGE EVERYTHING INTO A MASTER ANALYTICS DATAFRAME ---
# print("🔗 Synthesizing Master Feature Matrix...")
# # Base data
# master_df = orders[['order_id', 'customer_id', 'feat_actual_delivery_days',
#                     'feat_days_before_deadline', 'feat_seller_handling_days',
#                     'feat_purchase_hour', 'feat_purchase_day_of_week', 'feat_purchase_month']]
#
# # Merge items and payment features
# master_df = master_df.merge(order_items_features, on='order_id', how='left')
# master_df = master_df.merge(payment_features, on='order_id', how='left')
#
# # Drop any row that might have missing item records due to data purging
# master_df = master_df.dropna(subset=['total_items_in_order'])
#
# print(f"\n🎉 Feature Engineering Complete! Generated Shape: {master_df.shape}")
# print(master_df.head())

# %%
date_cols = [
    'order_purchase_timestamp',
    'order_approved_at', 
    'order_delivered_carrier_date', 
    'order_delivered_customer_date', 
    'order_estimated_delivery_date'
]
for col in date_cols:
    orders_df_c[col] = pd.to_datetime(orders_df_c[col])

orders_df_c['estimated_delivery_days'] = (orders_df_c['order_estimated_delivery_date'] - orders_df_c['order_purchase_timestamp']).dt.days
orders_df_c['actual_delivery_days'] = (orders_df_c['order_delivered_customer_date'] - orders_df_c['order_purchase_timestamp']).dt.days
orders_df_c['seller_handling_days'] = (orders_df_c['order_delivered_carrier_date'] - orders_df_c['order_purchase_timestamp']).dt.days
orders_df_c['carrier2customer_delivery_days'] = (orders_df_c['order_delivered_customer_date'] - orders_df_c['order_delivered_carrier_date']).dt.days
orders_df_c['delay'] = (orders_df_c['order_delivered_customer_date']-orders_df_c['order_estimated_delivery_date']).dt.days
orders_df_c.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp   order_approved_at  \
# 0    delivered      2017-10-02 10:56:33 2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37 2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49 2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06 2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39 2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
# Total order value
order_items_df_c.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# ...

# %%
order_items_df_c['total_order_value'] = order_items_df_c['price']+order_items_df_c['freight_value']
order_items_df_c.head()
# Out:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value  total_order_value
# 0  2017-09-19 09:45:35   58.90          13.29              72.19
# 1  2017-05-03 11:05:13  239.90          19.93             259.83
# ...

# %%
customer_order_count = orders_df_c.groupby('customer_id',as_index=False)['order_id'].count()
customer_order_count
# Out:
#                             customer_id  order_id
# 0      00012a2ce6f8dcda20d059ce98491703         1
# 1      000161a058600d5901f007fab4c27140         1
# 2      0001fd6190edaaf884bcaf3d49edf079         1
# 3      0002414f95344307404f0ace7a26f1d5         1
# 4      000379cdec625522490c315e70c7a9fb         1
# ...                                 ...       ...
# 99436  fffecc9f79fd8c764f843e9951b11341         1
# 99437  fffeda5b6d849fbd39689bb92087f431         1
# 99438  ffff42319e9b2d713724ae527742af25         1
# 99439  ffffa3172527f765de70084a7e53aae8         1
# 99440  ffffe8b65bbe3087b653a978c870db99         1
#
# [99441 rows x 2 columns]

# %%
customer_order_count[customer_order_count>1]
# Out:
# Series([], Name: order_id, dtype: int64)

# %%
customer_order_count.max()
# Out:
# np.int64(1)

# %%
# Payments made by customers
customer_payment_df = order_payments_df_c.merge(orders_df_c[['order_id','customer_id']], on='order_id', how='left')
customer_payment_df
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value                       customer_id
# ...

# %%
customer_total_spending = customer_payment_df.groupby('customer_id',as_index=False)['payment_value'].sum()
customer_total_spending.sort_values(by='payment_value',ascending=False)
# Out:
#                             customer_id  payment_value
# 8546   1617b1357756262bfa56ab541c47bc16       13664.08
# 91984  ec5b2ba62e574342386871631fafd3fc        7274.88
# 77521  c6e2731c5b391845f6800c97401a43a9        6929.31
# 95123  f48d464a0baaea338cb25f816991ab1f        6922.21
# 24771  3fd6777bbce08a352fddd04e4a7cc8f6        6726.66
# ...                                 ...            ...
# 9456   184e8e8e48937145eb96c721ef1f0747          10.07
# 65094  a790343ca6f3fee08112d678b43aa7c5           9.59
# 20653  3532ba38a3fd242259a514ac2b6ae6b6           0.00
# 64966  a73c1f73f5772cf801434bf984b0b1a7           0.00
# 9908   197a2a6a77da93f678ea0d379f21da0a           0.00
#
# [99440 rows x 2 columns]

# %%
order_payments_df_c[order_payments_df_c['order_id']=='00010242fe8c5a6d1ba2dd792cb16214']
# Out:
#                                order_id  payment_sequential payment_type  \
# 85283  00010242fe8c5a6d1ba2dd792cb16214                   1  credit_card
#
#        payment_installments  payment_value
# 85283                     2          72.19

# %%
#Revenue generated by each seller
seller_revenue = order_items_df_c.groupby('seller_id',as_index=False)[['price','freight_value']].sum()
seller_revenue['total_revenue'] = seller_revenue['price']+seller_revenue['freight_value']
seller_revenue.sort_values(by='total_revenue',ascending=False)
# Out:
#                              seller_id      price  freight_value  \
# 857   4869f7a5dfa277a7dca6462dcf3b52b2  229472.63       20168.07
# 1535  7c67e1448b00f6e969d365cea6b010ab  187923.89       51612.55
# 1013  53243585a1d6dc2643021fd1853d8905  222776.05       13080.63
# 881   4a3ca9315b744ce9f8e9374361493884  200472.92       35067.04
# 3024  fa1c13f2614d7b5c4749cbc52fecda94  194042.03       10042.70
# ...                                ...        ...            ...
# 1370  702835e4b785b67a084280efca355756       7.60          10.96
# 869   4965a7002cca77301c82d3f91b82e1a9       8.49           7.87
# 373   1fa2d3def6adfa70e58c276bb64fe5bb       6.90           9.00
# 1465  77128dec4bec4878c37ab7d6169d6f26       6.50           8.72
# 2519  cf6f6bc4df3999b9c6440f124fb2f687       3.50           8.72
#
#       total_revenue
# 857       249640.70
# 1535      239536.44
# 1013      235856.68
# 881       235539.96
# 3024      204084.73
# ...             ...
# 1370          18.56
# ...

# %%
#Average order value
no_of_orders=order_payments_df_c['order_id'].value_counts().sum()
order_totals = order_payments_df_c.groupby('order_id')['payment_value'].sum()

avg_order_value = order_totals.mean()
display(no_of_orders)
display(order_totals)
avg_order_value
# Out:
# np.int64(103886)
# order_id
# 00010242fe8c5a6d1ba2dd792cb16214     72.19
# 00018f77f2f0320c557190d7a144bdd3    259.83
# 000229ec398224ef6ca0657da4fc703e    216.87
# 00024acbcdf0a6daa1e931b038114c75     25.78
# 00042b26cf59d7ce69dfabb4e55b4fd9    218.04
#                                      ...
# fffc94f6ce00a00581880bf54a75a037    343.40
# fffcd46ef2263f404302a634eb57f7eb    386.53
# fffce4705a9662cd70adb13d4a31832d    116.85
# fffe18544ffabc95dfada21779c9644f     64.71
# fffe41c64501cc87c801fd61db3f6244     55.79
# Name: payment_value, Length: 99440, dtype: float64
# np.float64(160.9902666934835)

# %%
# Seller order count
seller_order_count = order_items_df_c.groupby('seller_id',as_index=False).agg(order_count=('order_id','count'))
seller_order_count
# Out:
#                              seller_id  order_count
# 0     0015a82c2db000af6aaaf3ae2ecb0532            3
# 1     001cca7ae9ae17fb1caed9dfb1094831          239
# 2     001e6ad469a905060d959994f1b41e4f            1
# 3     002100f778ceb8431b7a1020ff7ab48f           55
# 4     003554e2dce176b5555353e4f3555ac8            1
# ...                                ...          ...
# 3090  ffcfefa19b08742c5d315f2791395ee5            1
# 3091  ffdd9f82b9a447f6f8d4b91554cc7dd3           20
# 3092  ffeee66ac5d5a62fe688b9d26f83f534           14
# 3093  fffd5413c0700ac820c7069d66d98c89           61
# 3094  ffff564a4f9085cd26170f4732393726           20
#
# [3095 rows x 2 columns]

# %%
# Product sales count
product_sales_count = order_items_df_c.groupby('product_id',as_index=False)['order_id'].count()
product_sales_count.rename(columns={'order_id':'Total qty sold'},inplace=True)

# %%
product_sales_count['Total qty sold'].max()
# Out:
# np.int64(527)

# %%
product_sales = products_df_c.merge(product_sales_count,on='product_id',how='left')
product_sales.rename(columns={'order_id':'Total qty sold'})
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32944  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32945  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32946  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32947  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32948  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...

# %%
product_sales[product_sales['Total qty sold']==product_sales['Total qty sold'].max()]
# Out:
#                              product_id product_category_name  \
# 13429  aca2eb7d00ea1a7b8ebd4e68314663af      moveis_decoracao
#
#        product_name_length  product_description_length  product_photos_qty  \
# 13429                 44.0                       903.0                 6.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 13429            2600.0               50.0               10.0
#
#        product_width_cm  Total qty sold
# 13429              30.0             527

# %%
freq_payment_type = order_payments_df_c['payment_type'].value_counts()
freq_payment_type.sort_values(ascending=False)
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
avg_payment_installment = order_payments_df_c['payment_installments'].mean()
avg_payment_installment
# Out:
# np.float64(2.853348863176944)
